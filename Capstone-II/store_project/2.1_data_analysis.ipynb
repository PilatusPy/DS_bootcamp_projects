# %%
#importing libs
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#download dataset and setting "Txn_date" as index
df = pd.read_csv("data_no_outliers.csv")
df = df.set_index('Txn_date')
df.index = pd.to_datetime(df.index)
df = df.sort_index()
df
# Out:
#              Invoice_id  Cust_id Product_Sub_category  Product_Category  Qty  \
# Txn_date
# 2016-01-02  80348907828   267124            Computers       Electronics    2
# 2016-01-02  45127479223   273949                 Kids             Books    1
# 2016-01-02  21830961921   267482      Audio and video       Electronics    4
# 2016-01-02  35789988197   267508                 Mens          Clothing    3
# 2016-01-02   4947037174   271239  Electric appliances  Home and kitchen    3
# ...                 ...      ...                  ...               ...  ...
# 2018-12-31  26100869804   273836              Cameras       Electronics    3
# 2018-12-31  83963970126   274655                 Kids          Clothing    5
# 2018-12-31  51849180620   273963              Cameras       Electronics    3
# 2018-12-31  55120134998   274052          Non-fiction             Books    3
# 2018-12-31  56380733343   273570                Women          Clothing    2
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 19776 entries, 2016-01-02 to 2018-12-31
# Data columns (total 9 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Invoice_id            19776 non-null  int64
#  1   Cust_id               19776 non-null  int64
#  2   Product_Sub_category  19776 non-null  object
#  3   Product_Category      19776 non-null  object
#  4   Qty                   19776 non-null  int64
#  5   Rate                  19776 non-null  int64
#  6   Tax                   19776 non-null  float64
#  7   Total_Amt             19776 non-null  float64
#  8   Store_type            19776 non-null  object
# dtypes: float64(2), int64(4), object(3)
# memory usage: 1.5+ MB

# %%
total_sales = df['Total_Amt'].sum()
total_sales
# Out:
# 50738362.35

# %%
#data analysis
#identifying 'unique_customer_number'

unique_customer_number = df['Cust_id'].nunique()
unique_customer_number
# Out:
# 5469

# %%
customer_freq = df['Cust_id'].value_counts()
customer_freq.describe()
# Out:
# count    5469.000000
# mean        3.616018
# std         1.769325
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         5.000000
# max        11.000000
# Name: Cust_id, dtype: float64

# %%
#how old is this store?

age = df.index.max() - df.index.min()
age
# Out:
# Timedelta('1094 days 00:00:00')

# %%
#let's build time based DF's

df['Year'] = df.index.year
df['Month'] = df.index.month
df['Day'] = df.index.day
#day of the week and weekends
df['DayOfWeek'] = df.index.dayofweek
df['Weekend'] = df['DayOfWeek'].apply(lambda x: 1 if x >= 5 else 0)

# %%
#Plot total monthly sales by year 
plt.figure(figsize=(12,6))
df.groupby(['Year', 'Month'])['Total_Amt'].sum().plot(kind='line', title='Monthly sales by year', ylabel = 'Total Sales ($ in Millions)')

plt.show()

# %%
#Plot total monthly sales 
plt.figure(figsize=(15,6))
df.groupby('Month')['Total_Amt'].sum().plot(kind='bar', title='Monthly sales', xlabel='Month (January - December)', ylabel = 'Total Sales ($ in Millions)')

plt.show()

# %%
#pivot plot All three Years monthly Sales on one plot

pivot_sales = pd.pivot_table(df, values='Total_Amt', index='Month', columns='Year', aggfunc='sum')
pivot_sales.plot(figsize=(15,6),kind='bar', title="Monthly Sales by Year", 
                 xlabel='Month (January - December)', 
                 ylabel='Total Sales ($ in Millions)')
# Out:
# <Axes: title={'center': 'Monthly Sales by Year'}, xlabel='Month (January - December)', ylabel='Total Sales ($ in Millions)'>

# %%
#pivot plot All three Years daily Sales on one plot

pivot_sales = pd.pivot_table(df, values='Total_Amt', index='DayOfWeek', columns='Year', aggfunc='sum')
pivot_sales.plot(figsize=(15,6),kind='bar', title="Daily Sales by Year", 
                 xlabel='Days of the Week (Monday - Sunday)', 
                 ylabel='Total Sales ($ in Millions)')
# Out:
# <Axes: title={'center': 'Daily Sales by Year'}, xlabel='Days of the Week (Monday - Sunday)', ylabel='Total Sales ($ in Millions)'>

# %%
#pivot plot All three Years monthly Sales on one plot

pivot_sales = pd.pivot_table(df, values='Total_Amt', index='Weekend', columns='Year', aggfunc='sum')
pivot_sales.plot(figsize=(15,6),kind='bar', title="Weekend Sales by Year", 
                 xlabel='Weekends (Saturday - Sunday)', 
                 ylabel='Total Sales ($ in Millions)')
# Out:
# <Axes: title={'center': 'Weekend Sales by Year'}, xlabel='Weekends (Saturday - Sunday)', ylabel='Total Sales ($ in Millions)'>

# %%
sales = df.groupby('Product_Category')['Total_Amt'].sum()


plt.figure(figsize=(10, 6))
sns.barplot(x=sales.index, y=sales.values, palette="coolwarm")
plt.xticks(rotation=-45)
plt.xlabel('Product Category')
plt.ylabel('Total Sales ($ in Millions)')
plt.title('Sales by Product Category')
plt.show()

# %%
#Plot in boxplot sales by category
plt.figure(figsize=(10, 6))
sns.boxplot(x=df['Product_Category'], y=df['Total_Amt'])
plt.xticks(rotation=-45)
plt.xlabel('Product Category')
plt.ylabel('Total Sales ($)')
plt.title('Sales by Product Category')
plt.show()

# %%
#Plot in boxplot sales by Sub_category
plt.figure(figsize=(15, 6))
sns.boxplot(x=df['Product_Sub_category'], y=df['Total_Amt'])
plt.xticks(rotation=-45)
plt.xlabel('Product Subcategory')
plt.ylabel('Total Sales ($)')
plt.title('Sales by Product Subcategory')
plt.show()

# %% [markdown]
# #Summary
#
# '''
# We have implemented Time series visualization.  This approach allowed a detailed understanding of sales trends over time.
#
# Monthly Sales Over Time: A time series plot was created to show the total monthly sales across three years. This visualization revealed key fluctuations in sales and we can identify potential seasonal trends and paterns.
#
# Daily Sales Analysis: The total sales for each day of the week were analyzed for each year. This day level analysis provided understanding of weekly sales patterns.
#
# Sales by Categories: Sales were also analyzed by categories.
#
# '''
